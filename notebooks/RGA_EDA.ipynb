# %% [markdown]
# # Exploring the data

# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/train.csv')

# View the first few rows of the data
df.head(-5)
# Out:
#               id        date  store_nbr                   family    sales  \
# 0              0  2013-01-01          1               AUTOMOTIVE    0.000
# 1              1  2013-01-01          1                BABY CARE    0.000
# 2              2  2013-01-01          1                   BEAUTY    0.000
# 3              3  2013-01-01          1                BEVERAGES    0.000
# 4              4  2013-01-01          1                    BOOKS    0.000
# ...          ...         ...        ...                      ...      ...
# 3000878  3000878  2017-08-15          9                MAGAZINES   11.000
# 3000879  3000879  2017-08-15          9                    MEATS  449.228
# 3000880  3000880  2017-08-15          9            PERSONAL CARE  522.000
# 3000881  3000881  2017-08-15          9             PET SUPPLIES    6.000
# 3000882  3000882  2017-08-15          9  PLAYERS AND ELECTRONICS    6.000
#
#          onpromotion
# 0                  0
# 1                  0
# ...

# %%
# Get summary statistics for the data
df.describe()
# Out:
#                  id     store_nbr         sales   onpromotion
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06
# mean   1.500444e+06  2.750000e+01  3.577757e+02  2.602770e+00
# std    8.662819e+05  1.558579e+01  1.101998e+03  1.221888e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.502218e+05  1.400000e+01  0.000000e+00  0.000000e+00
# 50%    1.500444e+06  2.750000e+01  1.100000e+01  0.000000e+00
# 75%    2.250665e+06  4.100000e+01  1.958473e+02  0.000000e+00
# max    3.000887e+06  5.400000e+01  1.247170e+05  7.410000e+02

# %%
# Group the data by a specific column
grouped = df.groupby('family')
grouped.mean()
# Out:
# /var/folders/05/0y50yhdd2x3830pg3mcctvwm0000gn/T/ipykernel_8711/2810566549.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean()
#                                    id  store_nbr        sales  onpromotion
# family
# AUTOMOTIVE                  1500427.5       27.5     6.101236     0.052597
# BABY CARE                   1500428.5       27.5     0.110528     0.000583
# BEAUTY                      1500429.5       27.5     3.715723     0.148269
# BEVERAGES                   1500430.5       27.5  2385.793151     9.973586
# BOOKS                       1500431.5       27.5     0.070797     0.000000
# BREAD/BAKERY                1500432.5       27.5   463.336254     3.643101
# CELEBRATION                 1500433.5       27.5     8.370469     0.073931
# ...

# %% [markdown]
# # We should now jsut try a random forest on this and do a first submission
